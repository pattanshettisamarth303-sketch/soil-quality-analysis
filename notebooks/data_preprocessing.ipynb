# %% [markdown]
# <a href="https://colab.research.google.com/github/pattanshettisamarth303-sketch/soil-quality-analysis/blob/main/notebooks/data_preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Replace with the exact copied link from your green Code button
# !git clone https://github.com/pattanshettisamarth303-sketch/soil-quality-analysis.git

# %cd soil-quality-analysis
# !ls -la
# Out:
# Cloning into 'soil-quality-analysis'...
# remote: Enumerating objects: 11, done.
# remote: Counting objects: 100% (11/11), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 11 (delta 1), reused 10 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (11/11), done.
# Resolving deltas: 100% (1/1), done.
# /content/soil-quality-analysis
# total 32
# drwxr-xr-x 6 root root 4096 Aug 31 15:18 .
# drwxr-xr-x 1 root root 4096 Aug 31 15:18 ..
# drwxr-xr-x 3 root root 4096 Aug 31 15:18 data
# drwxr-xr-x 8 root root 4096 Aug 31 15:18 .git
# -rw-r--r-- 1 root root  211 Aug 31 15:18 .gitignore
# drwxr-xr-x 2 root root 4096 Aug 31 15:18 notebooks
# -rw-r--r-- 1 root root   24 Aug 31 15:18 README.md
# drwxr-xr-x 2 root root 4096 Aug 31 15:18 src

# %%
# 1. Create directories for raw data
# !mkdir -p data/raw/tabular data/raw/images

# 2. Upload kaggle.json for authentication
from google.colab import files
print("Upload your kaggle.json file:")
uploaded = files.upload()

# 3. Configure Kaggle credentials
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# 4. Download and setup Tabular Dataset
# !kaggle datasets download -d atharvaingle/crop-recommendation-dataset -p data/raw/tabular/
# !unzip -q data/raw/tabular/*.zip -d data/raw/tabular/
# !mv data/raw/tabular/Crop_recommendation.csv data/raw/tabular/soil_test_data.csv 2>/dev/null || true
# !rm -f data/raw/tabular/*.zip

# 5. Download and setup Image Dataset
# !kaggle datasets download -d prasanshasatpathy/soil-types -p data/raw/images/
# !unzip -q data/raw/images/*.zip -d data/raw/images/
# !rm -f data/raw/images/*.zip

# 6. Verify directory structure
# !ls -R data/raw
# Out:
# Upload your kaggle.json file:
#      <input type="file" id="files-5bfca4aa-8a9b-403f-b403-403f64dd8070" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5bfca4aa-8a9b-403f-b403-403f64dd8070">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# ...

# %%
# Move class folders directly under data/raw/images/
# !mv data/raw/images/'Soil types'/* data/raw/images/
# !rm -rf data/raw/images/'Soil types'

# Verify final image folder structure
# !ls -l data/raw/images
# Out:
# total 3176
# drwxr-xr-x 2 root root    4096 Aug 31 15:35 'Black Soil'
# drwxr-xr-x 2 root root    4096 Aug 31 15:35 'Cinder Soil'
# drwxr-xr-x 2 root root    4096 Aug 31 15:35 'Laterite Soil'
# drwxr-xr-x 2 root root    4096 Aug 31 15:35 'Peat Soil'
# -rw-r--r-- 1 root root 3230259 Jun 20  2021  soil-types.zip
# drwxr-xr-x 2 root root    4096 Aug 31 15:35 'Yellow Soil'

# %%
# !rm -f data/raw/images/soil-types.zip

# %%
import os
import pandas as pd

# 1. Inspect Tabular Dataset
df = pd.read_csv('data/raw/tabular/soil_test_data.csv')
print(f"Tabular Data Dimensions: {df.shape}")
display(df.head(3))

# 2. Inspect Image Dataset
classes = [d for d in os.listdir('data/raw/images') if os.path.isdir(f'data/raw/images/{d}')]
print(f"\nImage Classes ({len(classes)} total):")
for c in sorted(classes):
    count = len(os.listdir(f'data/raw/images/{c}'))
    print(f" • {c}: {count} images")
# Out:
# Tabular Data Dimensions: (2200, 8)
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# Image Classes (5 total):
#  • Black Soil: 37 images
#  • Cinder Soil: 30 images
#  • Laterite Soil: 30 images
#  • Peat Soil: 30 images
#  • Yellow Soil: 29 images
